# %%
import numpy as np
import matplotlib.pyplot as plt



# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")



plt.scatter(X, Y, color='g', label='Data Points')  # Data points
plt.plot(X, m*X + c, color='m', label='Fitted Line')  # Regression line
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
#Note: This regression line that is plotted does not accurately show the randomized points that were created.


import numpy as np
import matplotlib.pyplot as plt



# Randomized data points
X = np.random.rand(20) * 20
Y = np.random.rand(20) * 20


# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")



plt.scatter(X, Y, color='b', label='Data Points')  # Given points
plt.plot(X, m*X + c, color='r', label='Fitted Line')  # Regression line (very innacurate)
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
# Out:
# Slope: -0.3420342277336814, Intercept: 15.142227538784478

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute x from 0 to 1 with steps of 0.01
X = np.arange(0, 1.01, 0.01)

# My chosen linear equation
my_m = 2.0
my_c = 1.0

# Adding in some random perturbation
perturbation = np.random.normal(0, 0.2, len(X))
Y = my_m * X + my_c + perturbation

# Using Least Squares to calculate m and c
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]



# Compute residual = actual value - predicted value
Ypredictions = m*X + c
residuals = Y - Ypredictions

# Max and Min residuals, chatGPT used to figure out argmax/min syntax
max_residual_index = np.argmax(np.abs(residuals))
min_residual_index = np.argmin(np.abs(residuals))




print("\nLargest Residual:")
print(f"X = {X[max_residual_index]:.2f}, Y = {Y[max_residual_index]:.4f}, Residual = {residuals[max_residual_index]:.4f}")

print("\nSmallest residual:")
print(f"X = {X[min_residual_index]:.2f}, Y = {Y[min_residual_index]:.4f}, Residual = {residuals[min_residual_index]:.4f}")

print(f"\nChosen Slope: {my_m}, Chosen Intercept: {my_c}")
print(f"Estimated Slope: {m}, Estimated Intercept: {c}")




# Plotting
plt.scatter(X, Y, s=10, label='Random Perturbation')
plt.plot(X, my_m*X + my_c, 'g', label='My Chosen Line')
plt.plot(X, m*X + c, 'r', label='Least Squares Fitted Line')
plt.scatter(X[max_residual_index], Y[max_residual_index], s=40, marker='x', label='Max Residual')
plt.scatter(X[min_residual_index], Y[min_residual_index], s=40, marker='o', label='Min Residual')
plt.legend(fontsize=7)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# Largest Residual:
# X = 0.48, Y = 2.4881, Residual = 0.5445
#
# Smallest residual:
# X = 0.14, Y = 1.2804, Residual = 0.0009
#
# Chosen Slope: 2.0, Chosen Intercept: 1.0
# Estimated Slope: 1.9534383590556028, Estimated Intercept: 1.0059492319841568
