# %%
#Note: Based on the output this does not converge. No matter how many iterations
#the solution actually diverges. This is most likely due to the structure of the matrix.
#Also Jacobi clearly takes longer in regard to runtime. 



import numpy as np
import time



A = np.array([
    [1, 2, 3, 0, 0],
    [2, 1, 2, 3, 0],
    [3, 2, 1, 2, 3],
    [0, 3, 2, 1, 2],
    [0, 0, 3, 2, 1]
], dtype=float) #define the given matrix as an array

b = np.array([14, 22, 33, 26, 22], dtype=float)

x0 = np.zeros(5)
tolerance = 1e-6
max_iterations = 250



def jacobi(A, b, x0, tolerance, max_iterations): #jacobi function from the power point slides
    n = len(b)
    x = x0.copy()
    errors = []
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        error = np.linalg.norm(x_new - x, ord=np.inf)
        errors.append(error)
        if error < tolerance:
            return x_new, k + 1, errors
        x = x_new
    return x, max_iterations, errors



def gauss_seidel(A, b, x0, tolerance, max_iterations): #gauss-seidel function from the power point slides
    n = len(b)
    x = x0.copy()
    errors = []
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        error = np.linalg.norm(x_new - x, ord=np.inf)
        errors.append(error)
        if error < tolerance:
            return x_new, k + 1, errors
        x = x_new
    return x, max_iterations, errors



# google forums and chatGPT used for the run time code
start = time.perf_counter() 
x_j, it_j, err_j = jacobi(A, b, x0, tolerance, max_iterations)
end = time.perf_counter()
jacobi_time = end - start

start = time.perf_counter()
x_gs, it_gs, err_gs = gauss_seidel(A, b, x0, tolerance, max_iterations)
end = time.perf_counter()
gs_time = end - start



print("Tolerance =", tolerance, "\n")

print("Jacobi:")
print("Solution:", x_j)
print(f"Iterations: {it_j}")
print(f"Runtime: {jacobi_time:.6e} seconds\n")

print("Gauss-Seidel:")
print("Solution:", x_gs)
print(f"Iterations: {it_gs}")
print(f"Runtime: {gs_time:.6e} seconds")
# Out:
# Tolerance = 1e-06
#
# Jacobi:
# Solution: [-1.82489647e+213 -2.26074922e+213 -2.81422102e+213 -2.26074922e+213
#  -1.82489647e+213]
# Iterations: 250
# Runtime: 1.168862e-02 seconds
#
# Gauss-Seidel:
# Solution: [ 1.75570379e+283 -2.26097903e+283 -7.90277169e+283  1.80315686e+284
#  -1.23548221e+284]
# Iterations: 250
# Runtime: 1.019851e-02 seconds
