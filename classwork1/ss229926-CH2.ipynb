# %%
num = 2025 #define number
num//2
num%2
print (num%2) #runs through 2025 (might be a better way to do this)

while num>1: #runs through the rest of the numbers
    num = num//2
    num%2
    print (num%2)
# Out:
# 1
# 0
# 0
# 1
# 0
# 1
# 1
# 1
# 1
# 1
# 1
