# %%
import numpy as np
import time

A = np.array([
    [0.582745, 0.48,     0.10,     0.00,     0.00],
    [0.48,     1.044129, 0.46,     0.10,     0.00],
    [0.10,     0.46,     1.10431,  0.44,     0.10],
    [0.00,     0.10,     0.44,     0.963889, 0.42],
    [0.00,     0.00,     0.10,     0.42,     0.522565]
], dtype=float)

b = np.array([
    1.162745,
    2.084129,
    2.20431,
    1.923889,
    1.042565
], dtype=float)


x0 = np.zeros(5)
tolerance = 1e-6
max_iterations = 250



def jacobi(A, b, x0, tolerance, max_iterations): #jacobi function from the power point slides
    n = len(b)
    x = x0.copy()
    errors = []
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        error = np.linalg.norm(x_new - x, ord=np.inf)
        errors.append(error)
        if error < tolerance:
            return x_new, k + 1, errors
        x = x_new
    return x, max_iterations, errors



def gauss_seidel(A, b, x0, tolerance, max_iterations): #gauss-seidel function from the power point slides
    n = len(b)
    x = x0.copy()
    errors = []
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        error = np.linalg.norm(x_new - x, ord=np.inf)
        errors.append(error)
        if error < tolerance:
            return x_new, k + 1, errors
        x = x_new
    return x, max_iterations, errors






print("Tolerance =", tolerance, "\n")

print("Jacobi:")
print("Solution:", x_j)
print(f"Iterations: {it_j}")

print("Gauss-Seidel:")
print("Solution:", x_gs)
print(f"Iterations: {it_gs}")
# Out:
# Tolerance = 1e-06
#
# Jacobi:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c98a3eff3a19> in <module>
#      74
#      75 print("Jacobi:")
# ---> 76 print("Solution:", x_j)
#      77 print(f"Iterations: {it_j}")
#      78
#
# NameError: name 'x_j' is not defined
