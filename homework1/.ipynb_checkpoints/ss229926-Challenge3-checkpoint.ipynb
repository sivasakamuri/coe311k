# %%
import random
import numpy
import matplotlib.pyplot as plt

def montecarlo_pi(number): #defining the actual monetecarlo randomizing function using random dots, a unit circle, and a square area
    count = 0
    for i in range(0,number):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        
        if (x*x + y*y < 1): #circle formula
            count = count + 1
    return 4*count/number

Pi = numpy.pi

samples = [] #arrays for data collection
errors1 = []
errors2 = []



for i in range(100):                
    calcPi = montecarlo_pi(1000)     
    true_error = abs(Pi - calcPi)
    relative_error = abs((Pi - calcPi) / Pi)

    samples.append(i + 1) #GPT used to properly understand how to do the individual 100 times 1000 samples
    errors1.append(true_error)
    errors2.append(relative_error)


    
plt.figure()
    
plt.subplot(2, 1, 1) #absolute error sub plot 
plt.plot(samples, errors1, 'b')
plt.xlabel("Run Number")
plt.ylabel("Absolute Error")
plt.title("Monte Carlo Pi Absolute Error")

plt.subplot(2, 1, 2) #relative error sub plot 
plt.plot(samples, errors2, 'r')
plt.xlabel("Run Number")
plt.ylabel("Relative Error")
plt.title("Monte Carlo Pi Relative Error")

plt.tight_layout() #GPT used to figure out how to fix overlapping graphs
plt.show()
  
    
print("Error Data (15 decemial places): ", errors1, errors2)
# Out:
# Error Data (15 decemial places):  [0.06559265358979305, 0.08159265358979306, 0.07840734641020708, 0.050407346410207055, 0.026407346410207033, 0.013592653589793002, 0.02159265358979301, 0.017592653589793006, 0.013592653589793002, 0.025592653589793013, 0.002407346410207012, 0.09040734641020709, 0.010407346410207019, 0.018407346410207026, 0.005592653589792995, 0.10559265358979308, 0.08559265358979307, 0.025592653589793013, 0.029592653589793017, 0.10159265358979308, 0.026407346410207033, 0.037592653589793024, 0.029592653589793017, 0.0064073464102070155, 0.05359265358979304, 0.07359265358979306, 0.010407346410207019, 0.062407346410207065, 0.030407346410207037, 0.1064073464102071, 0.08959265358979307, 0.07040734641020707, 0.08559265358979307, 0.06559265358979305, 0.06559265358979305, 0.09359265358979307, 0.049592653589793034, 0.005592653589792995, 0.017592653589793006, 0.017592653589793006, 0.037592653589793024, 0.025592653589793013, 0.07759265358979306, 0.04159265358979303, 0.013592653589793002, 0.04240734641020705, 0.07359265358979306, 0.10159265358979308, 0.0064073464102070155, 0.07840734641020708, 0.005592653589792995, 0.013592653589793002, 0.05359265358979304, 0.02159265358979301, 0.02159265358979301, 0.08640734641020709, 0.08640734641020709, 0.06959265358979305, 0.16559265358979314, 0.12240734641020667, 0.009592653589792999