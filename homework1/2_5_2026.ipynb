# %%
i = 2147483648
print(i)
# Out:
# 2147483648

# %%
i+2**-53
# Out:
# 2147483648.0

# %%
for i in range(0,100):
    calculated_pi = montecarlo_pi(1000)
    true_pi = numpy.pi
    true_error = math.abs(true_pi - calculated_pi)
    relative_error = math.abs((true.pi - calculated_pi)/(true_pi))

    print(calculated_pi, true_error, relative_error)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bce091d37933> in <module>
#       1 for i in range(0,100):
# ----> 2     calculated_pi = montecarlo_pi(1000)
#       3     true_pi = numpy.pi
#       4     true_error = math.abs(true_pi - calculated_pi)
#       5     relative_error = math.abs((true.pi - calculated_pi)/(true_pi))
#
# NameError: name 'montecarlo_pi' is not defined
