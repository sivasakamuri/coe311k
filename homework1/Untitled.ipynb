# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "Papa"
print(name)
# Out:
# Papa

# %%
num1 = 5
print(num1)
# Out:
# 5

# %%
a = "Hello"
b = True 
type(a)
# Out:
# str

# %%
number1 = 5.0/2
number2 = 5/2
print(number1)
print(number2)
# Out:
# 2.5
# 2.5

# %%
numIn = input("Enter a number")
print(numIn)
# Out:
# Enter a number7
# 7

# %%
myfile= open("test.dat",'w')
myfile.write(numIn)
myfile.write("Hello World")
myfile.close()

# %%
if(a>b):print("A is greater than B")
if(b>a):
    print("B is greater than A")
    print("Conditions are awesome!")
print("All done!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-df7a680db2a1> in <module>
# ----> 1 if(a>b):print("A is greater than B")
#       2 if(b>a):
#       3     print("B is greater than A")
#       4     print("Conditions are awesome!")
#       5 print("All done!")
#
# TypeError: '>' not supported between instances of 'str' and 'bool'

# %%
for r in range(1,3):
        print(r, r**2)
# Out:
# 1 1
# 2 4

# %%
mylist = ["Charlie", 10, "yellow", 42, "Alex", 9, "black", 21]
for t in mylist:
    print(t)
# Out:
# Charlie
# 10
# yellow
# 42
# Alex
# 9
# black
# 21

# %%
import random

def montecarlo_pi(number_of_shots):
    for i in range(0,number_of_shots):
        x = random.uniform(-1,1)
        y = random.uniform(-1,1)
    if (x*x + y*y < 1):
        number_of_hits = number_of_hits + 1
    return 4*number_of_hits/number_of_shots

# %%
montecarlo_pi(100)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-25-39951abf8d23> in <module>
# ----> 1 montecarlo_pi(100)
#
# <ipython-input-24-95423f208cf2> in montecarlo_pi(number_of_shots)
#       6         y = random.uniform(-1,1)
#       7     if (x*x + y*y < 1):
# ----> 8         number_of_hits = number_of_hits + 1
#       9     return 4*number_of_hits/number_of_shots
#
# UnboundLocalError: local variable 'number_of_hits' referenced before assignment

# %%
import matplotlib.pyplot as plt
import numpy as np
