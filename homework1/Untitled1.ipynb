# %%
#Solving a Second ODE using Euler's method, first part
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def euler_method(y0, v0, t_start, t_end, h):
    t_values = np.arange(t_start, t_end + h, h)
    y_values = np.zeros(len(t_values))
    v_values = np.zeros(len(t_values))

    y_values[0] = y0
    v_values[0] = v0

    for i in range(1, len(t_values)):
        y_n = y_values[i-1]
        v_n = v_values[i-1]

        y_values[i] = y_n + h * v_n
        v_values[i] = v_n + h * (-2*z*w*v_n - w**2 * y_n)

    return t_values, y_values, v_values


plt.figure()

h = 0.01
t_e, y_e, v_e = euler_method(y_0, v_0, t_start, t_end, h)
v_rk, y_rk, t_rk = runge_kutta_4(velocity, y_0, v_0, t_start, t_end, h)

plt.plot(t_e, y_e, label='Euler')
plt.plot(t_rk, y_rk, label='RK4')

plt.xlabel('Time (s)')
plt.ylabel('Displacement (m)')
plt.title('Euler vs RK4 Comparison')
plt.legend()
plt.grid()
plt.show()


plt.figure()

plt.plot(t_e, v_e, label='Euler Velocity')
plt.plot(t_rk, v_rk, label='RK4 Velocity')

plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.title('Velocity Comparison')
plt.legend()
plt.grid()
plt.show()


plt.figure()

plt.plot(y_rk, v_rk)

plt.xlabel('Displacement (m)')
plt.ylabel('Velocity (m/s)')
plt.title('Phase Portrait')
plt.grid()
plt.show()


plt.figure()

h_test = [0.5, 1.0, 2.0]

for h in h_test:
    t_s, y_s, _ = euler_method(y_0, v_0, t_start, t_end, h)
    plt.plot(t_s, y_s, label=f'h={h}')

plt.xlabel('Time (s)')
plt.ylabel('Displacement (m)')
plt.title('Euler Stability Test')
plt.legend()
plt.grid()
plt.show()


def analytical_solution(t):
    wd = w * np.sqrt(1 - z**2)
    C1 = y_0
    C2 = (v_0 + z*w*y_0) / wd
    return np.exp(-z*w*t) * (C1*np.cos(wd*t) + C2*np.sin(wd*t))


h_values_error = [0.1, 0.05, 0.01]
euler_errors = []
rk4_errors = []

for h in h_values_error:
    t_vals, y_e, _ = euler_method(y_0, v_0, t_start, t_end, h)
    v_rk, y_rk, t_rk = runge_kutta_4(velocity, y_0, v_0, t_start, t_end, h)

    y_true = analytical_solution(t_vals)

    error_euler = np.max(np.abs(y_true - y_e))
    error_rk4 = np.max(np.abs(y_true - y_rk))

    euler_errors.append(error_euler)
    rk4_errors.append(error_rk4)


plt.figure()

plt.loglog(h_values_error, euler_errors, 'o-', label='Euler Error')
plt.loglog(h_values_error, rk4_errors, 'o-', label='RK4 Error')

plt.xlabel('Step size (h)')
plt.ylabel('Max Error')
plt.title('Error vs Step Size (Log-Log)')
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5841cdd20954> in <module>
#      25
#      26 h = 0.01
# ---> 27 t_e, y_e, v_e = euler_method(y_0, v_0, t_start, t_end, h)
#      28 v_rk, y_rk, t_rk = runge_kutta_4(velocity, y_0, v_0, t_start, t_end, h)
#      29
#
# NameError: name 'y_0' is not defined
